# %%
from langchain_tavily import TavilySearch
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearch(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# {'query': 'ChatGPT version releases and updates from 2022 to 2026',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/ChatGPT',
#    'title': 'ChatGPT - Wikipedia',
#    'content': '| Developer | OpenAI |\n| Release | November 30, 2022 (3 years ago) (2022-11-30) |\n| Stable release | June 18, 2026 (2 months ago) (2026-06-18) |\n|  |\n| Engine | GPT-5.6 |\n| Operating system |  Web platform  iOS  Android "Android (operating system)")  macOS  Windows  iPadOS |\n| Platform | Cloud computing platforms |\n| Available in | 59 languages |\n| Type |  Chatbot  Large language model  Generative pre-trained transformer |\n| License | Proprietary service |\n| Website | chatgpt.com |\n\n \n\n|  |',
#    'score': 0.9446333,
#    'raw_content': None,
#    'id': 'f1543a-00'},
#   {'url': 'https://wpexperts.io/blog/chatgpt-version-history',
#    'title': 'ChatGPT Version History List, Changelog & Latest Releases',
#    'content': 'ChatGPT 5.3\n\nGPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026.\n\nIt improves collaboration and supports full-cycle software development. It offers more accurate answers. \n\nChatGPT 5.2\n\nDecember 2025\n\nGPT-5.2 supports routine tasks and learning. Users were allowed to ask technical queries in a more conversational tone.\n\nChatGPT 5.1\n\nNovember 2025 [...] GpT-5.2 was released on December 11, 2025. The latest version supports both professionals and beginners. GPT-5.2 Instant, the latest model, suits everyday tasks and learning. This version is useful for professionals seeking how-tos, walkthroughs, and answers to technical questions, presented in a conversational tone. [...] | ChatGPT 5.3 | GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026. | It improves collaboration and supports full-cycle software development. It offers more accurate answers. |\n| ChatGPT 5.2 | December 2025 | GPT-5.2 supports routine tasks and learning. Users were allowed to ask technical queries in a more conversational tone. |',
#    'score': 0.9416167,
#    'raw_content': None,
#    'id': '5e5e94-01'}],
#  'response_time': 1.94,
#  'request_id': 'c19b3f3f-0398-4694-b460-2c4515442509'}

# %%
for r in results.get('results', []):
    print(r.get('content'))
# Out:
# | Developer | OpenAI |
# | Release | November 30, 2022 (3 years ago) (2022-11-30) |
# | Stable release | June 18, 2026 (2 months ago) (2026-06-18) |
# |  |
# | Engine | GPT-5.6 |
# | Operating system |  Web platform  iOS  Android "Android (operating system)")  macOS  Windows  iPadOS |
# | Platform | Cloud computing platforms |
# | Available in | 59 languages |
# | Type |  Chatbot  Large language model  Generative pre-trained transformer |
# | License | Proprietary service |
# | Website | chatgpt.com |
#
#
#
# |  |
# ChatGPT 5.3
#
# GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026.
#
# It improves collaboration and supports full-cycle software development. It offers more accurate answers.
#
# ChatGPT 5.2
#
# December 2025
#
# GPT-5.2 supports routine tasks and learning. Users were allowed to ask technical queries in a more conversational tone.
#
# ChatGPT 5.1
#
# November 2025 [...] GpT-5.2 was released on December 11, 2025. The latest version supports both professionals and beginners. GPT-5.2 Instant, the latest model, suits everyday tasks and learning. This version is useful for professionals seeking how-tos, walkthroughs, and answers to technical questions, presented in a conversational tone. [...] | ChatGPT 5.3 | GPT-5.3-Codex was launched in February 2026. GPT-5.3 Instant was launched in March 2026. | It improves collaboration and supports full-cycle software development. It offers more accurate answers. |
# | ChatGPT 5.2 | December 2025 | GPT-5.2 supports routine tasks and learning. Users were allowed to ask technical queries in a more conversational tone. |
